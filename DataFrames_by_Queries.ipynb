# %%
# Dependencies
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path

# %%
# Reference the file where the CSV is located
csv_path1 = Path("Average_Car_Price_By_Bracket.csv")
csv_path2 = Path("Cars_Sold_By_Dealership.csv")
csv_path3 = Path("Most_Purchased_Vehicle_By_Bracket.csv")

# Import the data into a Pandas DataFrame
acpbb_df = pd.read_csv(csv_path1, low_memory=False)
csbs_df = pd.read_csv(csv_path2, low_memory=False)
mpvbb_df = pd.read_csv(csv_path3, low_memory=False)

# %%
acpbb_df.head(50)
# Out:
#    avg_income_less_than_50000  avg_income_50000_to_150000  \
# 0                     27884.3                    26500.17
#
#    avg_income_greater_than_150001
# 0                        28149.09

# %%
csbs_df.head(50)
# Out:
#                                         dealer_name  num_cars_sold  \
# 0                                         U-Haul CO           1247
# 1                                     Classic Chevy            623
# 2                              Rabun Used Car Sales           1313
# 3                                   Iceberg Rentals            627
# 4                             Enterprise Rent A Car            625
# 5                 Scrivener Performance Engineering           1246
# 6                        Gartner Buick Hyundai Saab            628
# 7                                  Saab-Belle Dodge           1251
# 8                                       Capitol KIA            628
# 9                                     Race Car Help           1253
# 10                           Chrysler of Tri-Cities            626
# 11                             Star Enterprises Inc           1249
# 12                                    Suburban Ford           1243
# ...

# %%
mpvbb_df.head(50)
# Out:
#          income_range  num_customers most_frequent_car
# 0             >150000          18625      Volvo Xterra
# 1  >50000 and <150000              6   Pontiac Sunfire
# 2              <50000           5275      Volvo Xterra

# %%
sns.set_theme(rc={'figure.figsize':(12,9)})

plot1 = sns.barplot(data=csbs_df, x="dealer_name", y="avg_car_price")
plot1.set_xticklabels(plot1.get_xticklabels(), rotation=90)


plot1
# Out:
# <Axes: xlabel='dealer_name', ylabel='avg_car_price'>
